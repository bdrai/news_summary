# %%
# !pip install --upgrade pip
# !pip install transformers==4.20.0
# !pip install datasets
# !pip install huggingface-hub
# !pip install nltk
# !pip install rouge-score
# !pip install keras-nlp==0.3.1

# %%
import nltk
import numpy as np
np.random.seed(26)
import pandas as pd
import tensorflow as tf
from tensorflow import keras
from datasets import load_dataset, load_metric
from transformers import AutoTokenizer
from transformers import TFAutoModelForSeq2SeqLM, DataCollatorForSeq2Seq
from transformers import AutoModelForSeq2SeqLM, Seq2SeqTrainingArguments, Seq2SeqTrainer
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
MAX_INPUT_LENGTH = 1024  # Maximum length of the input to the model
MIN_TARGET_LENGTH = 5  # Minimum length of the output by the model
MAX_TARGET_LENGTH = 512  # Maximum length of the output by the model
BATCH_SIZE = 8  # Batch-size for training our model
LEARNING_RATE = 2e-5  # Learning-rate for training our model
MAX_EPOCHS = 1  # Maximum number of epochs we will train the model for
N_ROWS = 1000

# This notebook is built on the t5-small checkpoint from the Hugging Face Model Hub
MODEL_CHECKPOINT = "t5-small"

# %%
train = pd.read_csv("cnn_dailymail/train.csv")
test = pd.read_csv("cnn_dailymail/test.csv")
val = pd.read_csv("cnn_dailymail/validation.csv")

sub_train = train.sample(N_ROWS*3)
sub_train.to_csv("cnn_dailymail/sub_train.csv", index=False)

sub_test = test.sample(N_ROWS)
sub_test.to_csv("cnn_dailymail/sub_test.csv", index=False)

sub_val = test.sample(N_ROWS)
sub_val.to_csv("cnn_dailymail/sub_validation.csv", index=False)

del train, test, val, sub_train, sub_test, sub_val

# %%
data_files = {"train": "sub_train.csv", "test": "sub_test.csv", "validation": "sub_validation.csv"}
dataset = load_dataset("cnn_dailymail/", data_files=data_files)
dataset
# Out:
# WARNING:datasets.builder:Found cached dataset csv (/root/.cache/huggingface/datasets/csv/cnn_dailymail-17a4b2f7458f634f/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317)
#   0%|          | 0/3 [00:00<?, ?it/s]
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'article', 'highlights'],
#         num_rows: 3000
#     })
#     test: Dataset({
#         features: ['id', 'article', 'highlights'],
#         num_rows: 1000
#     })
#     validation: Dataset({
#         features: ['id', 'article', 'highlights'],
#         num_rows: 1000
#     })
# })

# %%
tokenizer = AutoTokenizer.from_pretrained(MODEL_CHECKPOINT)

# %%
prefix = "summarize: "

# %%
def preprocess_function(examples):
    inputs = [prefix + doc for doc in examples["article"]]
    model_inputs = tokenizer(inputs, max_length=MAX_INPUT_LENGTH, truncation=True)

    # Setup the tokenizer for targets
    with tokenizer.as_target_tokenizer():
        labels = tokenizer(examples["highlights"], max_length=MAX_TARGET_LENGTH, truncation=True)

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

# %%
tokenized_datasets = dataset.map(preprocess_function, batched=True)
# Out:
# Map:   0%|          | 0/3000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]

# %%
tokenized_datasets
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'article', 'highlights', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 3000
#     })
#     test: Dataset({
#         features: ['id', 'article', 'highlights', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 1000
#     })
#     validation: Dataset({
#         features: ['id', 'article', 'highlights', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 1000
#     })
# })

# %%
batch_size = 8
model_name = "t5-small-summarization-fine-tuned"
model_dir = f"Models/{model_name}"

args = Seq2SeqTrainingArguments(
    model_dir,
    evaluation_strategy="steps",
    eval_steps=30,
    logging_strategy="steps",
    logging_steps=10,
    save_strategy="steps",
    save_steps=20,
    learning_rate=4e-5,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    weight_decay=0.01,
    save_total_limit=3,
    num_train_epochs=1,
    predict_with_generate=True,
    fp16=True,
    load_best_model_at_end=True,
    metric_for_best_model="rouge1"
)

# %%
data_collator = DataCollatorForSeq2Seq(tokenizer)
metric = load_metric("rouge")
# Out:
# <ipython-input-19-c1c4517d1828>:2: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   metric = load_metric("rouge")
# Downloading builder script:   0%|          | 0.00/2.17k [00:00<?, ?B/s]

# %%
def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    decoded_preds = tokenizer.batch_decode(predictions, skip_special_tokens=True)
    
    # Replace -100 in the labels as we can't decode them.
    labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)
    
    # Rouge expects a newline after each sentence
    decoded_preds = ["\n".join(nltk.sent_tokenize(pred.strip())) for pred in decoded_preds]
    decoded_labels = ["\n".join(nltk.sent_tokenize(label.strip())) for label in decoded_labels]
    
    # Compute ROUGE scores
    result = metric.compute(predictions=decoded_preds, references=decoded_labels, use_stemmer=True)

    # Extract ROUGE f1 scores
    result = {key: value.mid.fmeasure * 100 for key, value in result.items()}
    
    # Add mean generated length to metrics
    prediction_lens = [np.count_nonzero(pred != tokenizer.pad_token_id)
                      for pred in predictions]
    result["gen_len"] = np.mean(prediction_lens)
    
    return {k: round(v, 4) for k, v in result.items()}

# %%
def model_init():
    return AutoModelForSeq2SeqLM.from_pretrained(MODEL_CHECKPOINT)

trainer = Seq2SeqTrainer(
    model_init=model_init,
    args=args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["validation"],
    data_collator=data_collator,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics
)
# Out:
# loading configuration file https://huggingface.co/t5-small/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/fe501e8fd6425b8ec93df37767fcce78ce626e34cc5edc859c662350cf712e41.d67b370cd9d75f81ad4eb421ee7b8db09e0b6a6c693b8c2b423af5d7bcac6205
# Model config T5Config {
#   "_name_or_path": "t5-small",
#   "architectures": [
#     "T5ForConditionalGeneration"
#   ],
#   "d_ff": 2048,
#   "d_kv": 64,
#   "d_model": 512,
#   "decoder_start_token_id": 0,
#   "dense_act_fn": "relu",
#   "dropout_rate": 0.1,
#   "eos_token_id": 1,
#   "feed_forward_proj": "relu",
#   "initializer_factor": 1.0,
#   "is_encoder_decoder": true,
#   "is_gated_act": false,
#   "layer_norm_epsilon": 1e-06,
#   "model_type": "t5",
#   "n_positions": 512,
#   "num_decoder_layers": 6,
#   "num_heads": 8,
#   "num_layers": 6,
#   "output_past": true,
#   "pad_token_id": 0,
#   "relative_attention_max_distance": 128,
#   "relative_attention_num_buckets": 32,
#   "task_specific_params": {
#     "summarization": {
#       "early_stopping": true,
#       "length_penalty": 2.0,
#       "max_length": 200,
#       "min_length": 30,
#       "no_repeat_ngram_size": 3,
#       "num_beams": 4,
#       "prefix": "summarize: "
#     },
#     "translation_en_to_de": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to German: "
#     },
#     "translation_en_to_fr": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to French: "
#     },
#     "translation_en_to_ro": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to Romanian: "
#     }
#   },
#   "transformers_version": "4.20.0",
#   "use_cache": true,
#   "vocab_size": 32128
# }
#
# https://huggingface.co/t5-small/resolve/main/pytorch_model.bin not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpw1v6cco3
# Downloading:   0%|          | 0.00/231M [00:00<?, ?B/s]
# storing https://huggingface.co/t5-small/resolve/main/pytorch_model.bin in cache at /root/.cache/huggingface/transformers/fee5a3a0ae379232608b6eed45d2d7a0d2966b9683728838412caccc41b4b0ed.ddacdc89ec88482db20c676f0861a336f3d0409f94748c209847b49529d73885
# creating metadata file for /root/.cache/huggingface/transformers/fee5a3a0ae379232608b6eed45d2d7a0d2966b9683728838412caccc41b4b0ed.ddacdc89ec88482db20c676f0861a336f3d0409f94748c209847b49529d73885
# loading weights file https://huggingface.co/t5-small/resolve/main/pytorch_model.bin from cache at /root/.cache/huggingface/transformers/fee5a3a0ae379232608b6eed45d2d7a0d2966b9683728838412caccc41b4b0ed.ddacdc89ec88482db20c676f0861a336f3d0409f94748c209847b49529d73885
# All model checkpoint weights were used when initializing T5ForConditionalGeneration.
#
# All the weights of T5ForConditionalGeneration were initialized from the model checkpoint at t5-small.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use T5ForConditionalGeneration for predictions without further training.
# Using cuda_amp half precision backend

# %%
trainer.train()
# Out:
# loading configuration file https://huggingface.co/t5-small/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/fe501e8fd6425b8ec93df37767fcce78ce626e34cc5edc859c662350cf712e41.d67b370cd9d75f81ad4eb421ee7b8db09e0b6a6c693b8c2b423af5d7bcac6205
# Model config T5Config {
#   "_name_or_path": "t5-small",
#   "architectures": [
#     "T5ForConditionalGeneration"
#   ],
#   "d_ff": 2048,
#   "d_kv": 64,
#   "d_model": 512,
#   "decoder_start_token_id": 0,
#   "dense_act_fn": "relu",
#   "dropout_rate": 0.1,
#   "eos_token_id": 1,
#   "feed_forward_proj": "relu",
#   "initializer_factor": 1.0,
#   "is_encoder_decoder": true,
#   "is_gated_act": false,
#   "layer_norm_epsilon": 1e-06,
#   "model_type": "t5",
#   "n_positions": 512,
#   "num_decoder_layers": 6,
#   "num_heads": 8,
#   "num_layers": 6,
#   "output_past": true,
#   "pad_token_id": 0,
#   "relative_attention_max_distance": 128,
#   "relative_attention_num_buckets": 32,
#   "task_specific_params": {
#     "summarization": {
#       "early_stopping": true,
#       "length_penalty": 2.0,
#       "max_length": 200,
#       "min_length": 30,
#       "no_repeat_ngram_size": 3,
#       "num_beams": 4,
#       "prefix": "summarize: "
#     },
#     "translation_en_to_de": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to German: "
#     },
#     "translation_en_to_fr": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to French: "
#     },
#     "translation_en_to_ro": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to Romanian: "
#     }
#   },
#   "transformers_version": "4.20.0",
#   "use_cache": true,
#   "vocab_size": 32128
# }
#
# loading weights file https://huggingface.co/t5-small/resolve/main/pytorch_model.bin from cache at /root/.cache/huggingface/transformers/fee5a3a0ae379232608b6eed45d2d7a0d2966b9683728838412caccc41b4b0ed.ddacdc89ec88482db20c676f0861a336f3d0409f94748c209847b49529d73885
# All model checkpoint weights were used when initializing T5ForConditionalGeneration.
#
# All the weights of T5ForConditionalGeneration were initialized from the model checkpoint at t5-small.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use T5ForConditionalGeneration for predictions without further training.
# The following columns in the training set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: article, id, highlights. If article, id, highlights are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running training *****
#   Num examples = 3000
#   Num Epochs = 1
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 375
#     <div>
#
#       <progress value='375' max='375' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [375/375 50:57, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge1</th>
#       <th>Rouge2</th>
#       <th>Rougel</th>
#       <th>Rougelsum</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>2.454800</td>
#       <td>2.276212</td>
#       <td>23.950500</td>
#       <td>10.849800</td>
#       <td>19.532100</td>
#       <td>22.514000</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>2.638600</td>
#       <td>2.106733</td>
#       <td>24.416200</td>
#       <td>11.464100</td>
#       <td>20.176800</td>
#       <td>23.031400</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>2.285800</td>
#       <td>2.009944</td>
#       <td>24.505800</td>
#       <td>11.588700</td>
#       <td>20.271000</td>
#       <td>23.145600</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>2.334100</td>
#       <td>1.949514</td>
#       <td>24.166300</td>
#       <td>11.511300</td>
#       <td>20.077300</td>
#       <td>22.858800</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>2.183100</td>
#       <td>1.904940</td>
#       <td>24.133900</td>
#       <td>11.510200</td>
#       <td>20.037600</td>
#       <td>22.788200</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>2.131500</td>
#       <td>1.874144</td>
#       <td>24.201800</td>
#       <td>11.528000</td>
#       <td>20.080900</td>
#       <td>22.831300</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>1.982500</td>
#       <td>1.857059</td>
#       <td>24.213400</td>
#       <td>11.439300</td>
#       <td>20.069300</td>
#       <td>22.824200</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>2.099900</td>
#       <td>1.845397</td>
#       <td>24.005500</td>
#       <td>11.259700</td>
#       <td>19.892700</td>
#       <td>22.701200</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>2.048700</td>
#       <td>1.836158</td>
#       <td>24.077900</td>
#       <td>11.378400</td>
#       <td>19.996600</td>
#       <td>22.771700</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.900300</td>
#       <td>1.830714</td>
#       <td>24.185700</td>
#       <td>11.427300</td>
#       <td>20.007700</td>
#       <td>22.840200</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>2.050700</td>
#       <td>1.823690</td>
#       <td>24.195100</td>
#       <td>11.465300</td>
#       <td>20.037800</td>
#       <td>22.861300</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>2.014000</td>
#       <td>1.815405</td>
#       <td>24.191400</td>
#       <td>11.435400</td>
#       <td>20.030300</td>
#       <td>22.853700</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>2.072900</td>
#       <td>1.808122</td>
#       <td>24.218400</td>
#       <td>11.486200</td>
#       <td>20.085700</td>
#       <td>22.884100</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>1.955300</td>
#       <td>1.804100</td>
#       <td>24.136900</td>
#       <td>11.419100</td>
#       <td>20.045100</td>
#       <td>22.804500</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>1.799800</td>
#       <td>1.803256</td>
#       <td>24.033400</td>
#       <td>11.337300</td>
#       <td>19.980900</td>
#       <td>22.733700</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>1.961000</td>
#       <td>1.802726</td>
#       <td>23.916100</td>
#       <td>11.241200</td>
#       <td>19.852100</td>
#       <td>22.618000</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>1.983900</td>
#       <td>1.800422</td>
#       <td>23.975100</td>
#       <td>11.254700</td>
#       <td>19.900400</td>
#       <td>22.688300</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>1.966700</td>
#       <td>1.797821</td>
#       <td>23.970000</td>
#       <td>11.249100</td>
#       <td>19.892300</td>
#       <td>22.663000</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>1.904400</td>
#       <td>1.795982</td>
#       <td>24.005500</td>
#       <td>11.271800</td>
#       <td>19.935000</td>
#       <td>22.715800</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>2.028200</td>
#       <td>1.793788</td>
#       <td>24.053700</td>
#       <td>11.282500</td>
#       <td>19.963700</td>
#       <td>22.751200</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>2.099400</td>
#       <td>1.791769</td>
#       <td>24.099500</td>
#       <td>11.335100</td>
#       <td>20.035900</td>
#       <td>22.783500</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>2.036100</td>
#       <td>1.790023</td>
#       <td>24.139600</td>
#       <td>11.366800</td>
#       <td>20.081100</td>
#       <td>22.839000</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>1.967700</td>
#       <td>1.787946</td>
#       <td>24.124000</td>
#       <td>11.400400</td>
#       <td>20.130400</td>
#       <td>22.844300</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>2.013100</td>
#       <td>1.787270</td>
#       <td>24.177400</td>
#       <td>11.437900</td>
#       <td>20.150400</td>
#       <td>22.892600</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>1.949400</td>
#       <td>1.786239</td>
#       <td>24.187800</td>
#       <td>11.467000</td>
#       <td>20.181400</td>
#       <td>22.889900</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>1.989800</td>
#       <td>1.785489</td>
#       <td>24.188200</td>
#       <td>11.457100</td>
#       <td>20.196600</td>
#       <td>22.908500</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>270</td>
#       <td>1.880100</td>
#       <td>1.785637</td>
#       <td>24.122100</td>
#       <td>11.428600</td>
#       <td>20.146700</td>
#       <td>22.852300</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>280</td>
#       <td>1.846100</td>
#       <td>1.786138</td>
#       <td>24.120500</td>
#       <td>11.428300</td>
#       <td>20.138000</td>
#       <td>22.846500</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>290</td>
#       <td>2.065500</td>
#       <td>1.786007</td>
#       <td>24.187900</td>
#       <td>11.484600</td>
#       <td>20.207300</td>
#       <td>22.883400</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>1.983100</td>
#       <td>1.785316</td>
#       <td>24.124400</td>
#       <td>11.399300</td>
#       <td>20.107200</td>
#       <td>22.829900</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>310</td>
#       <td>1.860400</td>
#       <td>1.785017</td>
#       <td>24.152300</td>
#       <td>11.416100</td>
#       <td>20.107600</td>
#       <td>22.851500</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>320</td>
#       <td>1.993200</td>
#       <td>1.784698</td>
#       <td>24.148100</td>
#       <td>11.439700</td>
#       <td>20.128800</td>
#       <td>22.851100</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>330</td>
#       <td>2.038300</td>
#       <td>1.784082</td>
#       <td>24.172100</td>
#       <td>11.444700</td>
#       <td>20.147400</td>
#       <td>22.877900</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>340</td>
#       <td>2.135600</td>
#       <td>1.783437</td>
#       <td>24.183400</td>
#       <td>11.458400</td>
#       <td>20.166000</td>
#       <td>22.896500</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>2.080900</td>
#       <td>1.783208</td>
#       <td>24.219000</td>
#       <td>11.496300</td>
#       <td>20.198500</td>
#       <td>22.935400</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>360</td>
#       <td>1.951300</td>
#       <td>1.782968</td>
#       <td>24.231900</td>
#       <td>11.500000</td>
#       <td>20.203500<
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: article, id, highlights. If article, id, highlights are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 8
#     <div>
#
#       <progress value='11' max='375' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 11/375 00:03 < 02:40, 2.26 it/s, Epoch 0.03/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='250' max='125' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [125/125 03:19]
#     </div>
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: article, id, highlights. If article, id, highlights are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 8
# Saving model checkpoint to Models/t5-small-summarization-fine-tuned/checkpoint-20
# Configuration saved in Models/t5-small-summarization-fine-tuned/checkpoint-20/config.json
# Model weights saved in Models/t5-small-summarization-fine-tuned/checkpoint-20/pytorch_model.bin
# tokenizer config file saved in Models/t5-small-summarization-fine-tuned/checkpoint-20/tokenizer_config.json
# Special tokens file saved in Models/t5-small-summarization-fine-tuned/checkpoint-20/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: article, id, highlights. If article, id, highlights are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: article, id, highlights. If article, id, highlights are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 8
# Saving model checkpoint to Models/t5-small-summarization-fine-tuned/checkpoint-40
# Configuration saved in Models/t5-small-summarization-fine-tuned/checkpoint-40/config.json
# Model weights saved in Models/t5-small-summarization-fine-tuned/checkpoint-40/pytorch_model.bin
# tokenizer config file saved in Models/t5-small-summarization-fine-tuned/checkpoint-40/tokenizer_config.json
# Special tokens file saved in Models/t5-small-summarization-fine-tuned/checkpoint-40/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: article, id, highlights. If article, id, highlights are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: article, id, highlights. If article, id, highlights are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 8
# Saving model checkpoint to Models/t5-small-summarization-fine-tuned/checkpoint-60
# Configuration saved in Models/t5-small-summarization-fine-tuned/checkpoint-60/config.json
# Model weights saved in Models/t5-small-summarization-fine-tuned/checkpoint-60/pytorch_model.bin
# tokenizer config file saved in Models/t5-small-summarization-fine-tuned/checkpoint-60/tokenizer_config.json
# Special tokens file saved in Models/t5-small-summarization-fine-tuned/checkpoint-60/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: article, id, highlights. If article, id, highlights are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: article, id, highlights. If article, id, highlights are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 8
# Saving model checkpoint to Models/t5-small-summarization-fine-tuned/checkpoint-80
# Configuration saved in Models/t5-small-summarization-fine-tuned/checkpoint-80/config.json
# Model weights saved in Models/t5-small-summarization-fine-tuned/checkpoint-80/pytorch_model.bin
# tokenizer config file saved in Models/t5-small-summarization-fine-tuned/checkpoint-80/tokenizer_config.json
# Special tokens file saved in Models/t5-small-summarization-fine-tuned/checkpoint-80/special_tokens_map.json
# Deleting older checkpoint [Models/t5-small-summarization-fine-tuned/checkpoint-40] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: article, id, highlights. If article, id, highlights are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: article, id, highlights. If article, id, highlights are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 8
# Saving model checkpoint to Models/t5-small-summarization-fine-tuned/checkpoint-100
# Configuration saved in Models/t5-small-summarization-fine-tuned/checkpoint-100/config.json
# Model weights saved in Models/t5-small-summarization-fine-tuned/checkpoint-100/pytorch_model.bin
# tokenizer config file saved in Models/t5-small-summarization-fine-tuned/checkpoint-100/tokenizer_config.json
# Special tokens file saved in Models/t5-small-summarization-fine-tuned/checkpoint-100/special_tokens_map.json
# Deleting older checkpoint [Models/t5-small-summarization-fine-tuned/checkpoint-60] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: article, id, highlights. If article, id, highlights are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: article, id, highlights. If article, id, highlights are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 8
# Saving model checkpoint to Models/t5-small-summarization-fine-tuned/checkpoint-120
# Configuration saved in Models/t5-small-summarization-fine-tuned/checkpoint-120/config.json
# Model weights saved in Models/t5-small-summarization-fine-tuned/checkpoint-120/pytorch_model.bin
# tokenizer config file saved in Models/t5-small-summarization-fine-tuned/checkpoint-120/tokenizer_config.json
# Special tokens file saved in Models/t5-small-summarization-fine-tuned/checkpoint-120/special_tokens_map.json
# Deleting older checkpoint [Models/t5-small-summarization-fine-tuned/checkpoint-80] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: article, id, highlights. If article, id, highlights are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: article, id, highlights. If article, id, highlights are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 8
# Saving model checkpoint to Models/t5-small-summarization-fine-tuned/checkpoint-140
# Configuration saved in Models/t5-small-summarization-fine-tuned/checkpoint-140/config.json
# Model weights saved in Models/t5-small-summarization-fine-tuned/checkpoint-140/pytorch_model.bin
# tokenizer config file saved in Models/t5-small-summarization-fine-tuned/checkpoint-140/tokenizer_config.json
# Special tokens file saved in Models/t5-small-summarization-fine-tuned/checkpoint-140/special_tokens_map.json
# Deleting older checkpoint [Models/t5-small-summarization-fine-tuned/checkpoint-100] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: article, id, highlights. If article, id, highlights are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: article, id, highlights. If article, id, highlights are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 8
# Saving model checkpoint to Models/t5-small-summarization-fine-tuned/checkpoint-160
# Configuration saved in Models/t5-small-summarization-fine-tuned/checkpoint-160/config.json
# Model weights saved in Models/t5-small-summarization-fine-tuned/checkpoint-160/pytorch_model.bin
# tokenizer config file saved in Models/t5-small-summarization-fine-tuned/checkpoint-160/tokenizer_config.json
# Special tokens file saved in Models/t5-small-summarization-fine-tuned/checkpoint-160/special_tokens_map.json
# Deleting older checkpoint [Models/t5-small-summarization-fine-tuned/checkpoint-120] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: article, id, highlights. If article, id, highlights are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: article, id, highlights. If article, id, highlights are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 8
# Saving model checkpoint to Models/t5-small-summarization-fine-tuned/checkpoint-180
# Configuration saved in Models/t5-small-summarization-fine-tuned/checkpoint-180/config.json
# Model weights saved in Models/t5-small-summarization-fine-tuned/checkpoint-180/pytorch_model.bin
# tokenizer config file saved in Models/t5-small-summarization-fine-tuned/checkpoint-180/tokenizer_config.json
# Special tokens file saved in Models/t5-small-summarization-fine-tuned/checkpoint-180/special_tokens_map.json
# Deleting older checkpoint [Models/t5-small-summarization-fine-tuned/checkpoint-140] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: article, id, highlights. If article, id, highlights are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: article, id, highlights. If article, id, highlights are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 8
# Saving model checkpoint to Models/t5-small-summarization-fine-tuned/checkpoint-200
# Configuration saved in Models/t5-small-summarization-fine-tuned/checkpoint-200/config.json
# Model weights saved in Models/t5-small-summarization-fine-tuned/checkpoint-200/pytorch_model.bin
# tokenizer config file saved in Models/t5-small-summarization-fine-tuned/checkpoint-200/tokenizer_config.json
# Special tokens file saved in Models/t5-small-summarization-fine-tuned/checkpoint-200/special_tokens_map.json
# Deleting older checkpoint [Models/t5-small-summarization-fine-tuned/checkpoint-160] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: article, id, highlights. If article, id, highlights are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: article, id, highlights. If article, id, highlights are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 8
# Saving model checkpoint to Models/t5-small-summarization-fine-tuned/checkpoint-220
# Configuration saved in Models/t5-small-summarization-fine-tuned/checkpoint-220/config.json
# Model weights saved in Models/t5-small-summarization-fine-tuned/checkpoint-220/pytorch_model.bin
# tokenizer config file saved in Models/t5-small-summarization-fine-tuned/checkpoint-220/tokenizer_config.json
# Special tokens file saved in Models/t5-small-summarization-fine-tuned/checkpoint-220/special_tokens_map.json
# Deleting older checkpoint [Models/t5-small-summarization-fine-tuned/checkpoint-180] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: article, id, highlights. If article, id, highlights are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: article, id, highlights. If article, id, highlights are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 8
# Saving model checkpoint to Models/t5-small-summarization-fine-tuned/checkpoint-240
# Configuration saved in Models/t5-small-summarization-fine-tuned/checkpoint-240/config.json
# Model weights saved in Models/t5-small-summarization-fine-tuned/checkpoint-240/pytorch_model.bin
# tokenizer config file saved in Models/t5-small-summarization-fine-tuned/checkpoint-240/tokenizer_config.json
# Special tokens file saved in Models/t5-small-summarization-fine-tuned/checkpoint-240/special_tokens_map.json
# Deleting older checkpoint [Models/t5-small-summarization-fine-tuned/checkpoint-200] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: article, id, highlights. If article, id, highlights are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: article, id, highlights. If article, id, highlights are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 8
# Saving model checkpoint to Models/t5-small-summarization-fine-tuned/checkpoint-260
# Configuration saved in Models/t5-small-summarization-fine-tuned/checkpoint-260/config.json
# Model weights saved in Models/t5-small-summarization-fine-tuned/checkpoint-260/pytorch_model.bin
# tokenizer config file saved in Models/t5-small-summarization-fine-tuned/checkpoint-260/tokenizer_config.json
# Special tokens file saved in Models/t5-small-summarization-fine-tuned/checkpoint-260/special_tokens_map.json
# Deleting older checkpoint [Models/t5-small-summarization-fine-tuned/checkpoint-220] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: article, id, highlights. If article, id, highlights are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: article, id, highlights. If article, id, highlights are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 8
# Saving model checkpoint to Models/t5-small-summarization-fine-tuned/checkpoint-280
# Configuration saved in Models/t5-small-summarization-fine-tuned/checkpoint-280/config.json
# Model weights saved in Models/t5-small-summarization-fine-tuned/checkpoint-280/pytorch_model.bin
# tokenizer config file saved in Models/t5-small-summarization-fine-tuned/checkpoint-280/tokenizer_config.json
# Special tokens file saved in Models/t5-small-summarization-fine-tuned/checkpoint-280/special_tokens_map.json
# Deleting older checkpoint [Models/t5-small-summarization-fine-tuned/checkpoint-240] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: article, id, highlights. If article, id, highlights are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: article, id, highlights. If article, id, highlights are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 8
# Saving model checkpoint to Models/t5-small-summarization-fine-tuned/checkpoint-300
# Configuration saved in Models/t5-small-summarization-fine-tuned/checkpoint-300/config.json
# Model weights saved in Models/t5-small-summarization-fine-tuned/checkpoint-300/pytorch_model.bin
# tokenizer config file saved in Models/t5-small-summarization-fine-tuned/checkpoint-300/tokenizer_config.json
# Special tokens file saved in Models/t5-small-summarization-fine-tuned/checkpoint-300/special_tokens_map.json
# Deleting older checkpoint [Models/t5-small-summarization-fine-tuned/checkpoint-260] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: article, id, highlights. If article, id, highlights are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: article, id, highlights. If article, id, highlights are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 8
# Saving model checkpoint to Models/t5-small-summarization-fine-tuned/checkpoint-320
# Configuration saved in Models/t5-small-summarization-fine-tuned/checkpoint-320/config.json
# Model weights saved in Models/t5-small-summarization-fine-tuned/checkpoint-320/pytorch_model.bin
# tokenizer config file saved in Models/t5-small-summarization-fine-tuned/checkpoint-320/tokenizer_config.json
# Special tokens file saved in Models/t5-small-summarization-fine-tuned/checkpoint-320/special_tokens_map.json
# Deleting older checkpoint [Models/t5-small-summarization-fine-tuned/checkpoint-280] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: article, id, highlights. If article, id, highlights are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: article, id, highlights. If article, id, highlights are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 8
# Saving model checkpoint to Models/t5-small-summarization-fine-tuned/checkpoint-340
# Configuration saved in Models/t5-small-summarization-fine-tuned/checkpoint-340/config.json
# Model weights saved in Models/t5-small-summarization-fine-tuned/checkpoint-340/pytorch_model.bin
# tokenizer config file saved in Models/t5-small-summarization-fine-tuned/checkpoint-340/tokenizer_config.json
# Special tokens file saved in Models/t5-small-summarization-fine-tuned/checkpoint-340/special_tokens_map.json
# Deleting older checkpoint [Models/t5-small-summarization-fine-tuned/checkpoint-300] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: article, id, highlights. If article, id, highlights are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: article, id, highlights. If article, id, highlights are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 8
# Saving model checkpoint to Models/t5-small-summarization-fine-tuned/checkpoint-360
# Configuration saved in Models/t5-small-summarization-fine-tuned/checkpoint-360/config.json
# Model weights saved in Models/t5-small-summarization-fine-tuned/checkpoint-360/pytorch_model.bin
# tokenizer config file saved in Models/t5-small-summarization-fine-tuned/checkpoint-360/tokenizer_config.json
# Special tokens file saved in Models/t5-small-summarization-fine-tuned/checkpoint-360/special_tokens_map.json
# Deleting older checkpoint [Models/t5-small-summarization-fine-tuned/checkpoint-320] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: article, id, highlights. If article, id, highlights are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1000
#   Batch size = 8
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from Models/t5-small-summarization-fine-tuned/checkpoint-20 (score: 24.4162).
# TrainOutput(global_step=375, training_loss=2.044940500895182, metrics={'train_runtime': 3057.7909, 'train_samples_per_second': 0.981, 'train_steps_per_second': 0.123, 'total_flos': 810923665391616.0, 'train_loss': 2.044940500895182, 'epoch': 1.0})

# %%
# !zip -r /content/models.zip /content/Models
# Out:
#   adding: content/Models/ (stored 0%)
#   adding: content/Models/t5-small-summarization-fine-tuned/ (stored 0%)
#   adding: content/Models/t5-small-summarization-fine-tuned/runs/ (stored 0%)
#   adding: content/Models/t5-small-summarization-fine-tuned/runs/Mar13_13-36-39_4b604639c0f6/ (stored 0%)
#   adding: content/Models/t5-small-summarization-fine-tuned/runs/Mar13_13-36-39_4b604639c0f6/1678714744.3052428/ (stored 0%)
#   adding: content/Models/t5-small-summarization-fine-tuned/runs/Mar13_13-36-39_4b604639c0f6/1678714744.3052428/events.out.tfevents.1678714744.4b604639c0f6.122.2 (deflated 63%)
#   adding: content/Models/t5-small-summarization-fine-tuned/runs/Mar13_13-36-39_4b604639c0f6/events.out.tfevents.1678714613.4b604639c0f6.122.0 (deflated 72%)
#   adding: content/Models/t5-small-summarization-fine-tuned/runs/Mar13_13-36-39_4b604639c0f6/1678714613.7530663/ (stored 0%)
#   adding: content/Models/t5-small-summarization-fine-tuned/runs/Mar13_13-36-39_4b604639c0f6/1678714613.7530663/events.out.tfevents.1678714613.4b604639c0f6.122.1 (deflated 63%)
#   adding: content/Models/t5-small-summarization-fine-tuned/.ipynb_checkpoints/ (stored 0%)
#   adding: content/Models/t5-small-summarization-fine-tuned/checkpoint-360/ (stored 0%)
#   adding: content/Models/t5-small-summarization-fine-tuned/checkpoint-360/special_tokens_map.json (deflated 86%)
#   adding: content/Models/t5-small-summarization-fine-tuned/checkpoint-360/training_args.bin (deflated 48%)
#   adding: content/Models/t5-small-summarization-fine-tuned/checkpoint-360/pytorch_model.bin (deflated 11%)
#   adding: content/Models/t5-small-summarization-fine-tuned/checkpoint-360/config.json (deflated 62%)
#   adding: content/Models/t5-small-summarization-fine-tuned/checkpoint-360/scheduler.pt (deflated 49%)
#   adding: content/Models/t5-small-summarization-fine-tuned/checkpoint-360/tokenizer.json (deflated 74%)
#   adding: content/Models/t5-small-summarization-fine-tuned/checkpoint-360/trainer_state.json (deflated 84%)
#   adding: content/Models/t5-small-summarization-fine-tuned/checkpoint-360/optimizer.pt (deflated 7%)
#   adding: content/Models/t5-small-summarization-fine-tuned/checkpoint-360/scaler.pt (deflated 55%)
#   adding: content/Models/t5-small-summarization-fine-tuned/checkpoint-360/rng_state.pth (deflated 28%)
#   adding: content/Models/t5-small-summarization-fine-tuned/checkpoint-360/tokenizer_config.json (deflated 83%)
